# %% [markdown]
# ## Importing Libraries for the project
#
# Libraries used for the project:
# 1) Pandas <br>
# 2) Seaborn <br>
# 3) Matplotlib <br>
# 3.1) from Matplotlib - pyplot

# %%
import pandas as pd
import seaborn as sns
import numpy as np

import matplotlib
import matplotlib.pyplot as plt
plt.style.use('ggplot')
from matplotlib.pyplot import figure

# %matplotlib inline
matplotlib.rcParams['figure.figsize'] = (12,8) # Adjusts the confihuration of the plots I will create.

# %% [markdown]
# ## Reading the data

# %%
movies_data = pd.read_csv('C:/Users/mares/OneDrive/Data_Science/Projects/Data_Analysis_Projects/Movie_Industry_Project/movies.csv')

# %%
movies_data.head()
# Out:
#                                              name rating      genre  year  \
# 0                                     The Shining      R      Drama  1980
# 1                                 The Blue Lagoon      R  Adventure  1980
# 2  Star Wars: Episode V - The Empire Strikes Back     PG     Action  1980
# 3                                       Airplane!     PG     Comedy  1980
# 4                                      Caddyshack      R     Comedy  1980
#
#                         released  score      votes         director  \
# 0  June 13, 1980 (United States)    8.4   927000.0  Stanley Kubrick
# 1   July 2, 1980 (United States)    5.8    65000.0   Randal Kleiser
# 2  June 20, 1980 (United States)    8.7  1200000.0   Irvin Kershner
# 3   July 2, 1980 (United States)    7.7   221000.0     Jim Abrahams
# 4  July 25, 1980 (United States)    7.3   108000.0     Harold Ramis
#
#                     writer            star         country      budget  \
# ...

# %% [markdown]
# ## Looking for missing data

# %%
for col in movies_data.columns:
    pct_missing = np.mean(movies_data[col].isnull())
    print(f'{col} - {pct_missing}%')
# Out:
# name - 0.0%
# rating - 0.010041731872717789%
# genre - 0.0%
# year - 0.0%
# released - 0.0002608242044861763%
# score - 0.0003912363067292645%
# votes - 0.0003912363067292645%
# director - 0.0%
# writer - 0.0003912363067292645%
# star - 0.00013041210224308815%
# country - 0.0003912363067292645%
# budget - 0.2831246739697444%
# gross - 0.02464788732394366%
# company - 0.002217005738132499%
# runtime - 0.0005216484089723526%

# %% [markdown]
# ## Data Cleaning

# %%
# Looking at data types for columns
movies_data.dtypes
# Out:
# name         object
# rating       object
# genre        object
# year          int64
# released     object
# score       float64
# votes       float64
# director     object
# writer       object
# star         object
# country      object
# budget      float64
# gross       float64
# company      object
# runtime     float64
# dtype: object

# %%
movies_data['budget'] = movies_data['budget'].astype('Int64')
movies_data['gross'] = movies_data['gross'].astype('Int64')

# %%
movies_data.dtypes
# Out:
# name         object
# rating       object
# genre        object
# year          int64
# released     object
# score       float64
# votes       float64
# director     object
# writer       object
# star         object
# country      object
# budget        Int64
# gross         Int64
# company      object
# runtime     float64
# dtype: object

# %%
movies_data
# Out:
#                                                 name rating      genre  year  \
# 0                                        The Shining      R      Drama  1980
# 1                                    The Blue Lagoon      R  Adventure  1980
# 2     Star Wars: Episode V - The Empire Strikes Back     PG     Action  1980
# 3                                          Airplane!     PG     Comedy  1980
# 4                                         Caddyshack      R     Comedy  1980
# ...                                              ...    ...        ...   ...
# 7663                                    More to Life    NaN      Drama  2020
# 7664                                     Dream Round    NaN     Comedy  2020
# 7665                                   Saving Mbango    NaN      Drama  2020
# 7666                                    It's Just Us    NaN      Drama  2020
# 7667                                       Tee em el    NaN     Horror  2020
#
# ...

# %%
#converting released to str
movies_data['released'] = movies_data['released'].astype('str')

# %%
# Split released into columns 
movies_data[['Month_released', 'Date_country']] = movies_data['released'].str.split(',', expand=True)

# %%
movies_data.head()
# Out:
#                                              name rating      genre  year  \
# 0                                     The Shining      R      Drama  1980
# 1                                 The Blue Lagoon      R  Adventure  1980
# 2  Star Wars: Episode V - The Empire Strikes Back     PG     Action  1980
# 3                                       Airplane!     PG     Comedy  1980
# 4                                      Caddyshack      R     Comedy  1980
#
#                         released  score      votes         director  \
# 0  June 13, 1980 (United States)    8.4   927000.0  Stanley Kubrick
# 1   July 2, 1980 (United States)    5.8    65000.0   Randal Kleiser
# 2  June 20, 1980 (United States)    8.7  1200000.0   Irvin Kershner
# 3   July 2, 1980 (United States)    7.7   221000.0     Jim Abrahams
# 4  July 25, 1980 (United States)    7.3   108000.0     Harold Ramis
#
#                     writer            star         country    budget  \
# ...

# %%
#movies_data = movies_data.drop(columns=['year_released'])

# %%
# movies_data = movies_data.drop(columns=['Year_released'])

# %%
movies_data.head()
# Out:
#                                              name rating      genre  year  \
# 0                                     The Shining      R      Drama  1980
# 1                                 The Blue Lagoon      R  Adventure  1980
# 2  Star Wars: Episode V - The Empire Strikes Back     PG     Action  1980
# 3                                       Airplane!     PG     Comedy  1980
# 4                                      Caddyshack      R     Comedy  1980
#
#                         released  score      votes         director  \
# 0  June 13, 1980 (United States)    8.4   927000.0  Stanley Kubrick
# 1   July 2, 1980 (United States)    5.8    65000.0   Randal Kleiser
# 2  June 20, 1980 (United States)    8.7  1200000.0   Irvin Kershner
# 3   July 2, 1980 (United States)    7.7   221000.0     Jim Abrahams
# 4  July 25, 1980 (United States)    7.3   108000.0     Harold Ramis
#
#                     writer            star         country    budget  \
# ...

# %%
movies_data.dtypes
# Out:
# name               object
# rating             object
# genre              object
# year                int64
# released           object
# score             float64
# votes             float64
# director           object
# writer             object
# star               object
# country            object
# budget              Int64
# gross               Int64
# company            object
# runtime           float64
# Month_released     object
# Date_country       object
# dtype: object

# %%
#Create for year released
movies_data['year_released'] = movies_data['Date_country'].astype(str).str[:5]

# %%
movies_data.head()
# Out:
#                                              name rating      genre  year  \
# 0                                     The Shining      R      Drama  1980
# 1                                 The Blue Lagoon      R  Adventure  1980
# 2  Star Wars: Episode V - The Empire Strikes Back     PG     Action  1980
# 3                                       Airplane!     PG     Comedy  1980
# 4                                      Caddyshack      R     Comedy  1980
#
#                         released  score      votes         director  \
# 0  June 13, 1980 (United States)    8.4   927000.0  Stanley Kubrick
# 1   July 2, 1980 (United States)    5.8    65000.0   Randal Kleiser
# 2  June 20, 1980 (United States)    8.7  1200000.0   Irvin Kershner
# 3   July 2, 1980 (United States)    7.7   221000.0     Jim Abrahams
# 4  July 25, 1980 (United States)    7.3   108000.0     Harold Ramis
#
#                     writer            star         country    budget  \
# ...

# %%
movies_data.sort_values(by=['gross'], inplace=False, ascending=False)
# Out:
#                                             name rating   genre  year  \
# 5445                                      Avatar  PG-13  Action  2009
# 7445                           Avengers: Endgame  PG-13  Action  2019
# 3045                                     Titanic  PG-13   Drama  1997
# 6663  Star Wars: Episode VII - The Force Awakens  PG-13  Action  2015
# 7244                      Avengers: Infinity War  PG-13  Action  2018
# ...                                          ...    ...     ...   ...
# 7663                                More to Life    NaN   Drama  2020
# 7664                                 Dream Round    NaN  Comedy  2020
# 7665                               Saving Mbango    NaN   Drama  2020
# 7666                                It's Just Us    NaN   Drama  2020
# 7667                                   Tee em el    NaN  Horror  2020
#
#                                released  score      votes       director  \
# ...

# %%
# Dealing with NA values
movies_data['gross'].isnull().sum()
# Out:
# 189

# %%
movies_data['gross'] = movies_data['gross'].fillna(0)
movies_data['gross'].isnull().sum()
movies_data
# Out:
#                                                 name rating      genre  year  \
# 0                                        The Shining      R      Drama  1980
# 1                                    The Blue Lagoon      R  Adventure  1980
# 2     Star Wars: Episode V - The Empire Strikes Back     PG     Action  1980
# 3                                          Airplane!     PG     Comedy  1980
# 4                                         Caddyshack      R     Comedy  1980
# ...                                              ...    ...        ...   ...
# 7663                                    More to Life    NaN      Drama  2020
# 7664                                     Dream Round    NaN     Comedy  2020
# 7665                                   Saving Mbango    NaN      Drama  2020
# 7666                                    It's Just Us    NaN      Drama  2020
# 7667                                       Tee em el    NaN     Horror  2020
#
# ...

# %%
movies_data['budget'].isnull().sum()
# Out:
# 2171

# %%
movies_data['budget'] = movies_data['budget'].fillna(0)
movies_data['budget'].isnull().sum()
movies_data
# Out:
#                                                 name rating      genre  year  \
# 0                                        The Shining      R      Drama  1980
# 1                                    The Blue Lagoon      R  Adventure  1980
# 2     Star Wars: Episode V - The Empire Strikes Back     PG     Action  1980
# 3                                          Airplane!     PG     Comedy  1980
# 4                                         Caddyshack      R     Comedy  1980
# ...                                              ...    ...        ...   ...
# 7663                                    More to Life    NaN      Drama  2020
# 7664                                     Dream Round    NaN     Comedy  2020
# 7665                                   Saving Mbango    NaN      Drama  2020
# 7666                                    It's Just Us    NaN      Drama  2020
# 7667                                       Tee em el    NaN     Horror  2020
#
# ...

# %% [markdown]
# ## Finding Correlation

# %%
movies_data.head()
# Out:
#                                              name rating      genre  year  \
# 0                                     The Shining      R      Drama  1980
# 1                                 The Blue Lagoon      R  Adventure  1980
# 2  Star Wars: Episode V - The Empire Strikes Back     PG     Action  1980
# 3                                       Airplane!     PG     Comedy  1980
# 4                                      Caddyshack      R     Comedy  1980
#
#                         released  score      votes         director  \
# 0  June 13, 1980 (United States)    8.4   927000.0  Stanley Kubrick
# 1   July 2, 1980 (United States)    5.8    65000.0   Randal Kleiser
# 2  June 20, 1980 (United States)    8.7  1200000.0   Irvin Kershner
# 3   July 2, 1980 (United States)    7.7   221000.0     Jim Abrahams
# 4  July 25, 1980 (United States)    7.3   108000.0     Harold Ramis
#
#                     writer            star         country    budget  \
# ...

# %%
# Budget high correlation
# Company - High correlation

#scatter plot with budget vs gross revenue

plt.scatter(x=movies_data['budget'], y=movies_data['gross'])
plt.title('Budget vs Gross Earnings')
plt.xlabel('Gross Earnings')
plt.ylabel('Budget for film')
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
movies_data.dtypes
# Out:
# name               object
# rating             object
# genre              object
# year                int64
# released           object
# score             float64
# votes             float64
# director           object
# writer             object
# star               object
# country            object
# budget              Int64
# gross               Int64
# company            object
# runtime           float64
# Month_released     object
# Date_country       object
# year_released      object
# dtype: object

# %%
# Plot budget vs Gross using seaborn

movies_data['budget'] = movies_data['budget'].astype('float')
movies_data['gross'] = movies_data['gross'].astype('float')
sns.regplot(x='budget', y='gross', data=movies_data, scatter_kws={'color' : 'red'}, line_kws={'color' : 'blue'})
# Out:
# <AxesSubplot:xlabel='budget', ylabel='gross'>

# %%
movies_data.corr(method='pearson')
# Out:
#              year     score     votes    budget     gross   runtime
# year     1.000000  0.097995  0.222945  0.309212  0.261900  0.120811
# score    0.097995  1.000000  0.409182  0.055665  0.186392  0.399451
# votes    0.222945  0.409182  1.000000  0.486862  0.632834  0.309212
# budget   0.309212  0.055665  0.486862  1.000000  0.750157  0.269510
# gross    0.261900  0.186392  0.632834  0.750157  1.000000  0.245235
# runtime  0.120811  0.399451  0.309212  0.269510  0.245235  1.000000

# %%
correlation_matrix = movies_data.corr(method='pearson')

sns.heatmap(correlation_matrix, annot=True)
plt.title('Correlation Matrix for Numeric Features')
plt.xlabel('Movie Features')
plt.ylabel('Movie Features')
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
movies_data_numerized = movies_data

for col_name in movies_data_numerized.columns:
    if(movies_data_numerized[col_name].dtype == 'object'):
        movies_data_numerized[col_name] = movies_data_numerized[col_name].astype('category')
        movies_data_numerized[col_name] = movies_data_numerized[col_name].cat.codes

movies_data_numerized
# Out:
#       name  rating  genre  year  released  score      votes  director  writer  \
# 0     6587       6      6  1980      1705    8.4   927000.0      2589    4014
# 1     5573       6      1  1980      1492    5.8    65000.0      2269    1632
# 2     5142       4      0  1980      1771    8.7  1200000.0      1111    2567
# 3      286       4      4  1980      1492    7.7   221000.0      1301    2000
# 4     1027       6      4  1980      1543    7.3   108000.0      1054     521
# ...    ...     ...    ...   ...       ...    ...        ...       ...     ...
# 7663  3705      -1      6  2020      2964    3.1       18.0      1500    2289
# 7664  1678      -1      4  2020      1107    4.7       36.0       774    2614
# 7665  4717      -1      6  2020       193    5.7       29.0      2061    2683
# 7666  2843      -1      6  2020      2817    NaN        NaN      1184    1824
# 7667  5394      -1     10  2020       391    5.7        7.0      2165    3344
#
# ...

# %%
movies_data_numerized.corr()
# Out:
#                     name    rating     genre      year  released     score  \
# name            1.000000 -0.008069  0.016355  0.011453 -0.010480  0.017097
# rating         -0.008069  1.000000  0.072423  0.008779  0.017208 -0.001314
# genre           0.016355  0.072423  1.000000 -0.081261  0.030429  0.027965
# year            0.011453  0.008779 -0.081261  1.000000  0.000077  0.097995
# released       -0.010480  0.017208  0.030429  0.000077  1.000000  0.042148
# score           0.017097 -0.001314  0.027965  0.097995  0.042148  1.000000
# votes           0.013088  0.033225 -0.145307  0.222945  0.016154  0.409182
# director        0.009079  0.019483 -0.015258 -0.020795 -0.001526  0.009559
# writer          0.009081 -0.005921  0.006567 -0.008656 -0.002784  0.019416
# star            0.006472  0.013405 -0.005477 -0.027242  0.015805 -0.001609
# country        -0.010737  0.081244 -0.037615 -0.070938 -0.023408 -0.133348
# ...

# %%
correlation_matric = movies_data_numerized.corr(method='pearson')
sns.heatmap(correlation_matric, annot=True)
plt.title('Correlation Matrix for Numeric Features')
plt.xlabel('Movie Features')
plt.ylabel('Movie Features')
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
corr_matrix = movies_data_numerized.corr()
corr_pairs = corr_matrix.unstack()
corr_pairs
# Out:
# name           name              1.000000
#                rating           -0.008069
#                genre             0.016355
#                year              0.011453
#                released         -0.010480
#                                    ...
# year_released  company          -0.026492
#                runtime           0.115317
#                Month_released   -0.011938
#                Date_country      0.944242
#                year_released     1.000000
# Length: 324, dtype: float64

# %%
sorted_pairs = corr_pairs.sort_values()
sorted_pairs
# Out:
# budget         genre           -0.334021
# genre          budget          -0.334021
# gross          genre           -0.234297
# genre          gross           -0.234297
#                votes           -0.145307
#                                   ...
# gross          gross            1.000000
# company        company          1.000000
# runtime        runtime          1.000000
# writer         writer           1.000000
# year_released  year_released    1.000000
# Length: 324, dtype: float64

# %%
high_corr = sorted_pairs[(sorted_pairs) > 0.5]
high_corr
# Out:
# gross           votes             0.632834
# votes           gross             0.632834
# budget          gross             0.750157
# gross           budget            0.750157
# year_released   Date_country      0.944242
# Date_country    year_released     0.944242
# year            year_released     0.967486
# year_released   year              0.967486
# Date_country    year              0.980716
# year            Date_country      0.980716
# Month_released  released          0.999759
# released        Month_released    0.999759
# name            name              1.000000
# Month_released  Month_released    1.000000
# rating          rating            1.000000
# genre           genre             1.000000
# year            year              1.000000
# released        released          1.000000
# score           score             1.000000
# votes           votes             1.000000
# Date_country    Date_country      1.000000
# director        director          1.000000
# ...

# %% [markdown]
# ## Conclusion

# %% [markdown]
# High Correlation found between :
# - Gross and the Votes (0.632834)
# - Budget and gross (0.750157)
#
# With the highest correlation between the budget and gross.
